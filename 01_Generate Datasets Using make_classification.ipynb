# %% [markdown]
# #   make_classification():
# -   n_samples: How many observations do you want to generate?
# -   n_features: The number of numerical features.
# -   n_informative: The number of features that are ‘useful.’ Only these features carry the signal that your model will use to classify the dataset.
# -   n_classes: The number of unique classes (values) for the target label.

# %% [markdown]
# ##  Binary Classification Dataset

# %%
from sklearn.datasets import make_classification
X,y = make_classification(
    n_samples=1000,
    n_features=5,
    n_informative=3,
    n_classes=2,
    random_state=0
)

# %%
import pandas as pd
df=pd.DataFrame(X,columns=['x1','x2','x3','x4','x5'])
df['y'] = y

# %%
df.sample(10)
# Out:
#            x1        x2        x3        x4        x5  y
# 617 -0.762713  0.127314 -0.494348 -0.900538 -0.683743  0
# 971 -0.611903  2.183098  0.064149  0.007281 -0.071312  0
# 863  0.252836  0.085693  0.174683  1.685513  2.708265  1
# 882  0.708077  0.936541  0.689898  1.402904  1.236592  1
# 232  1.854756 -0.439686  1.193328  0.612698 -1.165572  1
# 903 -0.740295  1.478430 -0.181260 -0.289729 -0.153381  0
# 283  1.572463  0.115579  1.118986  0.755354 -0.758045  1
# 829  0.874217  0.006844  0.589012  1.962053  2.419838  0
# 344 -0.700944  1.295552 -0.198545 -0.017425  0.367078  0
# 553  0.196756  1.896365  0.553356  1.010157  0.803916  1
